# %%
def lcs(a, b):
    c = [[(0, 'H')] * (len(b) + 1) for _ in range(len(a) + 1)]

    for i in range(1, len(a) + 1):
        for j in range(1, len(b) + 1):
            if a[i - 1] == b[j - 1]:
                c[i][j] = (c[i - 1][j - 1][0] + 1, 'D')
            else:
                if c[i - 1][j][0] >= c[i][j - 1][0]:
                    c[i][j] = (c[i - 1][j][0], 'U')
                else:
                    c[i][j] = (c[i][j - 1][0], 'L')

    print("Matrix (Length, Direction):")
    for row in c:
        print(row)

    lcs_sequence = []
    i, j = len(a), len(b)
    while i > 0 and j > 0:
        if c[i][j][1] == 'D':
            lcs_sequence.append(a[i - 1])
            i -= 1
            j -= 1
        elif c[i][j][1] == 'U':
            i -= 1
        else:
            j -= 1

    lcs_sequence.reverse()

    return c[len(a)][len(b)][0], ''.join(lcs_sequence)

X = "AGCCCTAAGGGCTACCTAGCTT"
Y = "GACAGCCTACAAGCGTTAGCTTG"

lcs_length, lcs_seq = lcs(a, b)
print(f"\nLCS Length: {lcs_length}")
print(f"LCS: {lcs_seq}")
# Out:
# Matrix (Length, Direction):
# [(0, 'H'), (0, 'H'), (0, 'H'), (0, 'H'), (0, 'H'), (0, 'H'), (0, 'H'), (0, 'H')]
# [(0, 'H'), (1, 'D'), (1, 'L'), (1, 'L'), (1, 'L'), (1, 'L'), (1, 'L'), (1, 'L')]
# [(0, 'H'), (1, 'U'), (1, 'U'), (1, 'U'), (1, 'U'), (1, 'U'), (1, 'U'), (1, 'U')]
# [(0, 'H'), (1, 'U'), (2, 'D'), (2, 'L'), (2, 'L'), (2, 'L'), (2, 'L'), (2, 'L')]
# [(0, 'H'), (1, 'U'), (2, 'U'), (2, 'U'), (3, 'D'), (3, 'L'), (3, 'L'), (3, 'L')]
# [(0, 'H'), (1, 'D'), (2, 'U'), (2, 'U'), (3, 'U'), (3, 'U'), (3, 'U'), (3, 'U')]
# [(0, 'H'), (1, 'U'), (2, 'U'), (2, 'U'), (3, 'U'), (3, 'U'), (3, 'U'), (4, 'D')]
# [(0, 'H'), (1, 'U'), (2, 'U'), (2, 'U'), (3, 'U'), (3, 'U'), (3, 'U'), (4, 'U')]
#
# LCS Length: 4
# LCS: GVET

# %%
def lcs(a, b):
    c = [[(0, 'H')] * (len(b) + 1) for _ in range(len(a) + 1)]

    for i in range(1, len(a) + 1):
        for j in range(1, len(b) + 1):
            if a[i - 1] == b[j - 1]:
                c[i][j] = (c[i - 1][j - 1][0] + 1, 'D')
            else:
                if c[i - 1][j][0] >= c[i][j - 1][0]:
                    c[i][j] = (c[i - 1][j][0], 'U')
                else:
                    c[i][j] = (c[i][j - 1][0], 'L')

    print("Matrix (Length, Direction):")
    for row in c:
        print(row)

    lcs_sequence = []
    i, j = len(a), len(b)
    while i > 0 and j > 0:
        if c[i][j][1] == 'D':
            lcs_sequence.append(a[i - 1])
            i -= 1
            j -= 1
        elif c[i][j][1] == 'U':
            i -= 1
        else:
            j -= 1

    lcs_sequence.reverse()

    return c[len(a)][len(b)][0], ''.join(lcs_sequence)

X = "AGCCCTAAGGGCTACCTAGCTT"
Y = "GACAGCCTACAAGCGTTAGCTTG"

lcs_length, lcs_seq = lcs(X,Y)
print(f"\nLCS Length: {lcs_length}")
print(f"LCS: {lcs_seq}")
# Out:
# Matrix (Length, Direction):
# [(0, 'H'), (0, 'H'), (0, 'H'), (0, 'H'), (0, 'H'), (0, 'H'), (0, 'H'), (0, 'H'), (0, 'H'), (0, 'H'), (0, 'H'), (0, 'H'), (0, 'H'), (0, 'H'), (0, 'H'), (0, 'H'), (0, 'H'), (0, 'H'), (0, 'H'), (0, 'H'), (0, 'H'), (0, 'H'), (0, 'H'), (0, 'H')]
# [(0, 'H'), (0, 'U'), (1, 'D'), (1, 'L'), (1, 'D'), (1, 'L'), (1, 'L'), (1, 'L'), (1, 'L'), (1, 'D'), (1, 'L'), (1, 'D'), (1, 'D'), (1, 'L'), (1, 'L'), (1, 'L'), (1, 'L'), (1, 'L'), (1, 'D'), (1, 'L'), (1, 'L'), (1, 'L'), (1, 'L'), (1, 'L')]
# [(0, 'H'), (1, 'D'), (1, 'U'), (1, 'U'), (1, 'U'), (2, 'D'), (2, 'L'), (2, 'L'), (2, 'L'), (2, 'L'), (2, 'L'), (2, 'L'), (2, 'L'), (2, 'D'), (2, 'L'), (2, 'D'), (2, 'L'), (2, 'L'), (2, 'L'), (2, 'D'), (2, 'L'), (2, 'L'), (2, 'L'), (2, 'D')]
# ...
